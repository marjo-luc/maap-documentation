# %%
from maap.maap import MAAP
maap = MAAP()
import os
import glob
import geopandas as gpd
from shapely.geometry import Point
import h5py

# %%
# %%time

granules = maap.searchGranule(short_name='ATL08', version='003', bounding_box="-77,-26,-73,0", limit=600)
for g in granules:
    g.getLocalPath('files/', overwrite=False)

print(f"Downloaded all files")
files = glob.glob('files/*')
points = []
elevation_low = []
height_above_ground = []
for idx in range(len(files)):
    try:
        f = h5py.File(files[idx], 'r')
        beams = ['gt1l', 'gt1r', 'gt2l', 'gt2r', 'gt3l', 'gt3r']
        for beam in beams:
            x, y, z = f[f"{beam}/land_segments/longitude"][:], f[f"{beam}/land_segments/latitude"][:], f[f"{beam}/land_segments/dem_h"][:]
            points.extend(list(map(Point, zip(x, y, z))))
            elevation_low.extend(f[f"{beam}/land_segments/terrain/h_te_best_fit"][:])
            try:
                height_above_ground.extend(f[f"{beam}/land_segments/canopy"][:])
            except:
                height_above_ground.extend([None] * len(x))
    except Exception as e:
        print(f"Skipping {files[idx]} because {e}")

df = gpd.GeoDataFrame({'geometry': points, 'ElevationLow': elevation_low, 'HeightAboveGround': height_above_ground}, crs='epsg:4326')
subset = df.cx[-77:-73, -26:0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <timed exec> in <module>
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# /opt/conda/lib/python3.7/site-packages/h5py/_hl/group.py in __getitem__(self, name)
#     262                 raise ValueError("Invalid HDF5 object reference")
#     263         else:
# --> 264             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     265
#     266         otype = h5i.get_type(oid)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5o.pyx in h5py.h5o.open()
#
# KeyError: 'Unable to open object (component not found)'

# %%
subset
# Out:
#                                        geometry  ElevationLow  \
# 5993    POINT Z (-73.05119 -10.42599 304.26987)    277.952515
# 5994    POINT Z (-73.05155 -10.42239 302.59036)    278.078552
# 5995    POINT Z (-73.06461 -10.29352 370.38980)    334.841766
# 5996    POINT Z (-73.06470 -10.29262 374.64694)    337.177429
# 5997    POINT Z (-73.06480 -10.29172 378.11005)    337.527802
# ...                                         ...           ...
# 190315   POINT Z (-75.59003 -0.07419 247.08476)    224.216782
# 190316   POINT Z (-75.59013 -0.07329 246.60645)    226.192749
# 190317   POINT Z (-75.59021 -0.07239 246.10155)    225.873352
# 190318   POINT Z (-75.59030 -0.07148 245.51677)    224.090225
# 190319   POINT Z (-75.59048 -0.06968 245.77660)    229.589417
#
#        HeightAboveGround
# 5993                None
# 5994                None
# 5995                None
# 5996                None
# 5997                None
# ...                  ...
# 190315              None
# 190316              None
# 190317              None
# 190318              None
# 190319              None
#
# [96501 rows x 3 columns]

# %%
for f in files:
    os.remove(f)

# %%
# import folium
# m = folium.Map(
#     location=[df.centroid[0].y, df.centroid[0].x],
#     zoom_start=10,
#     tiles='Stamen Terrain'
# )


# folium.GeoJson(
#     df,
#     name = "geojson"
# ).add_to(m)

# m
